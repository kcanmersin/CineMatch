# %%
import pandas as pd

movieId_to_name = pd.read_csv(r'C:\courses\CSE343SE\archive\movies_out.csv')

# %%
movieId_to_name.head(10)
# Out:
#                              title
# id
# 862                      Toy Story  \
# 8844                       Jumanji
# 15602             Grumpier Old Men
# 31357            Waiting to Exhale
# 11862  Father of the Bride Part II
# 949                           Heat
# 11860                      Sabrina
# 45325                 Tom and Huck
# 9091                  Sudden Death
# 710                      GoldenEye
#
#                                                 overview  popularity
# id
# 862    Led by Woody, Andy's toys live happily in his ...          21  \
# 8844   When siblings Judy and Peter discover an encha...          17
# 15602  A family wedding reignites the ancient feud be...          11
# 31357  Cheated on, mistreated and stepped on, the wom...           3
# 11862  Just when George Banks has recovered from his ...           8
# 949    Obsessive master thief, Neil McCauley leads a ...          17
# 11860  An ugly duckling having undergone a remarkable...           6
# ...

# %%
movieId_to_name.set_index('id', inplace=True)

# %%
# i want to see films with index [2059, 2897, 2307, 2775, 1059, 2746, 2898, 243, 1896, 1890] 

movies = movieId_to_name[movieId_to_name.index.isin([2059, 2897, 2307, 2775, 1059, 2746, 2898, 243, 1896, 1890])]

movies
# Out:
# Empty DataFrame
# Columns: [title, overview, popularity, release_date, revenue, runtime, tagline]
# Index: []
